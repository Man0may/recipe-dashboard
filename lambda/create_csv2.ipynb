# %%
import requests
import pandas as pd
from datetime import datetime
import json
url = "https://tasty-co1.p.rapidapi.com/recipes/list"

headers = {
	"x-rapidapi-key": "a9b872d815msheb48533bde663d8p19e6d7jsn4fef49382b49",
	"x-rapidapi-host": "tasty-co1.p.rapidapi.com"
}
# Make the API call
response = requests.get(url, headers=headers)
# Convert the response to a DataFrame
df = pd.DataFrame(response.json())
# Save DataFrame to CSV
df.to_csv('tasty_recipes.csv', index=False)
# DataFram to json
df.to_json('tasty_recipes.json', orient='records', lines=True)
# Out:
#                                       name  \
# 0           Low-Carb Avocado Chicken Salad
# 1                  Blueberry Cream Muffins
# 2                 Cinnamon Roll Cheesecake
# 3                 Tomato And Anchovy Pasta
# 4  Browned “Butter” Chocolate Chip Cookies
#
#                                          description  \
# 0  This chicken salad is a lunchtime delight! Pac...
# 1
# 2  Get ready for a dessert extravaganza with this...
# 3  Savor the bold flavors of this Tomato and Anch...
# 4  Don’t worry if you’re skipping the eggs and bu...
#
#                                        thumbnail_url  \
# 0  https://img.buzzfeed.com/thumbnailer-prod-us-e...
# 1  https://img.buzzfeed.com/tasty-app-user-assets...
# 2  https://img.buzzfeed.com/tasty-app-user-assets...
# 3  https://img.buzzfeed.com/thumbnailer-prod-us-e...
# 4  https://img.buzzfeed.com/thumbnailer-prod-us-e...
#
#                                   original_video_url  total_time_minutes
# ...
